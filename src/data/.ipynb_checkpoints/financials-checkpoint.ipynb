# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
index = "MSFT"

# %%
import pyfmpcloud
from pyfmpcloud import settings
from pyfmpcloud import company_valuation as cv

# %%
key = 'b3cc29d88d7238b82433a5d8cd26df03'

# %%
settings.set_apikey('b3cc29d88d7238b82433a5d8cd26df03')

# %%
_bs = cv.balance_sheet('MSFT', period = 'quarter', ftype = 'full')
_is = cv.income_statement('MSFT', period = 'quarter', ftype = 'full')
_cf = cv.cash_flow_statement('MSFT', period = 'quarter', ftype = 'full')

# %%
marketCap = cv.market_capitalization('MSFT', history = 'daily')
rating = cv.rating('MSFT', history = 'daily')

# %%
def getData(k):
    url = 'https://fmpcloud.io/api/v3/'+ k +'/MSFT?period=quarter&limit=800&apikey=' + key
    read_data = requests.get(url)
    soup = BeautifulSoup(read_data.content, 'html.parser')
    return soup

# %%
_is = getData('income-statement')

# %%
_bs
# Out:
#         date symbol fillingDate         acceptedDate period  \
# 0 2020-09-30   MSFT  2020-10-27  2020-10-27 16:21:58     Q1
# 1 2020-06-30   MSFT  2020-07-30  2020-07-30 20:44:46     Q4
# 2 2020-03-31   MSFT  2020-04-29  2020-04-29 16:11:11     Q3
# 3 2019-12-31   MSFT  2020-01-29  2020-01-29 16:08:43     Q2
# 4 2019-09-30   MSFT  2019-10-23  2019-10-23 16:09:48     Q1
#
#    cashAndCashEquivalents  shortTermInvestments  cashAndShortTermInvestments  \
# 0             17205000000          120772000000                 137977000000
# 1             13576000000          122951000000                 136527000000
# 2             11710000000          125900000000                 137610000000
# 3              8864000000          125367000000                 134231000000
# 4             13117000000          123492000000                 136609000000
#
#    netReceivables   inventory  ...  retainedEarnings  \
# 0     22851000000  2705000000  ...       39193000000
# 1     32011000000  1895000000  ...       34566000000
# 2     22699000000  1644000000  ...       32012000000
# 3     23525000000  1823000000  ...       30739000000
# 4     19087000000  2622000000  ...       27240000000
#
#    accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# 0                               3110000000                   73525000000
# 1                               3186000000                   -2292000000
# 2                               2676000000                   -2477000000
# 3                               -255000000                   -1900000000
# 4                                -61000000                   -2126000000
#
#    totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0             123392000000                           301001000000
# 1             118304000000                           301311000000
# 2             114501000000                           285449000000
# 3             110109000000                           282794000000
# 4             106061000000                           278955000000
#
#    totalInvestments    totalDebt      netDebt  \
# 0      123875000000  63552000000  46347000000
# 1      125916000000  72823000000  59247000000
# 2      128560000000  75220000000  63510000000
# 3      128122000000  78359000000  69495000000
# 4      126176000000  77360000000  64243000000
#
#                                                 link  \
# 0  https://www.sec.gov/Archives/edgar/data/789019...
# 1  https://www.sec.gov/Archives/edgar/data/789019...
# 2  https://www.sec.gov/Archives/edgar/data/789019...
# 3  https://www.sec.gov/Archives/edgar/data/789019...
# 4  https://www.sec.gov/Archives/edgar/data/789019...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/789019...
# 1  https://www.sec.gov/Archives/edgar/data/789019...
# 2  https://www.sec.gov/Archives/edgar/data/789019...
# 3  https://www.sec.gov/Archives/edgar/data/789019...
# 4  https://www.sec.gov/Archives/edgar/data/789019...
#
# [5 rows x 46 columns]

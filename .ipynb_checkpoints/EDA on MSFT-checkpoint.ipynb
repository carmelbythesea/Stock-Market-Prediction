# %%
! pip install babypandas
! pip install --user OpenBlender

# %%
import OpenBlender
import pandas as pd
import numpy as np
import json

# %%
msft = pd.read_csv("MSFT.csv")

# %%
msft
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-10-23  136.880005  137.449997  135.610001  137.240005  135.695190
# 1    2019-10-24  139.389999  140.419998  138.669998  139.940002  138.364792
# 2    2019-10-25  139.339996  141.139999  139.199997  140.729996  139.145874
# 3    2019-10-28  144.399994  145.669998  143.509995  144.190002  142.566940
# 4    2019-10-29  144.080002  144.500000  142.649994  142.830002  141.222244
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-10-16  220.149994  222.289993  219.320007  219.660004  219.660004
# 249  2020-10-19  220.419998  222.300003  213.720001  214.220001  214.220001
# 250  2020-10-20  215.800003  217.369995  213.089996  214.649994  214.649994
# 251  2020-10-21  213.119995  216.919998  213.119995  214.800003  214.800003
# 252  2020-10-22  213.929993  216.054993  211.699997  214.889999  214.889999
#
#        Volume
# 0    29844600
# 1    37029300
# ...

# %%
msft.plot(kind = 'line', x="Date", y="Open")

# %%
msft.plot()

# %%
msft = msft.assign(Change = msft.get("Close") - msft.get("Open"))

# %%
msft.plot(x="Date", y="Change")

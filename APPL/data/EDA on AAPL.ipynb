# %%
import OpenBlender

# %%
import pandas as pd
import numpy as np
import json

# %%
import os

# %%
apple = pd.read_csv('AAPL.csv')

# %%
apple
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.101261
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095978
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088934
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.091135
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093777
# ...           ...         ...         ...         ...         ...         ...
# 10011  2020-08-26  126.180000  126.992500  125.082497  126.522499  126.522499
# 10012  2020-08-27  127.142502  127.485001  123.832497  125.010002  125.010002
# 10013  2020-08-28  126.012497  126.442497  124.577499  124.807503  124.807503
# 10014  2020-08-31  127.580002  131.000000  126.000000  129.039993  129.039993
# 10015  2020-09-01  132.759995  134.800003  130.529999  134.179993  134.179993
#
#             Volume
# ...

# %%
apple.plot()
apple.plot(x="Date", y="Open")

# %%
apple_copy = apple[9500:10016]

# %%
apple_copy.plot()
apple_copy.plot(x="Date", y="Open")

# %%
apple_copy["Change"] = apple_copy["Close"] - apple_copy["Open"]
# Out:
# C:\Users\j3543\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
apple_copy.plot(x = "Date", y = "Change")
